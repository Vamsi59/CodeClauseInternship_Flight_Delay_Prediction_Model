# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
flights=pd.read_csv('flights.csv')
flights=flights.sample(n=100000)
flights.head()
# Out:
# C:\Users\alapa\AppData\Local\Temp\ipykernel_12640\664831390.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   flights=pd.read_csv('flights.csv')
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 5652583  2015     12   21            1      MQ           3235      N905MQ
# 5611793  2015     12   18            5      EV           4389      N12564
# 96010    2015      1    7            3      OO           6196      N732SK
# 3817197  2015      8   25            2      DL           2528      N953AT
# 3608399  2015      8   12            3      OO           4542      N452SW
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 5652583            BMI                 DFW                  720  ...
# 5611793            CAK                 ORD                 1357  ...
# 96010              ONT                 IAH                  701  ...
# 3817197            CLE                 ATL                 1419  ...
# 3608399            IDA                 SLC                 1820  ...
#
#          ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 5652583         941.0           -6.0         0          0
# 5611793        1421.0          -13.0         0          0
# 96010          1230.0           20.0         0          0
# 3817197        1548.0          -19.0         0          0
# 3608399        1915.0            0.0         0          0
#
#          CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# 5652583                  NaN               NaN             NaN            NaN
# 5611793                  NaN               NaN             NaN            NaN
# 96010                    NaN              16.0             0.0            4.0
# 3817197                  NaN               NaN             NaN            NaN
# 3608399                  NaN               NaN             NaN            NaN
#
#          LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 5652583                  NaN            NaN
# 5611793                  NaN            NaN
# 96010                    0.0            0.0
# 3817197                  NaN            NaN
# 3608399                  NaN            NaN
#
# [5 rows x 31 columns]

# %%
flights.shape
# Out:
# (100000, 31)

# %%
flights.isnull().values.any()
# Out:
# True

# %%
flights.isnull().sum()
# Out:
# YEAR                       0
# MONTH                      0
# DAY                        0
# DAY_OF_WEEK                0
# AIRLINE                    0
# FLIGHT_NUMBER              0
# TAIL_NUMBER              267
# ORIGIN_AIRPORT             0
# DESTINATION_AIRPORT        0
# SCHEDULED_DEPARTURE        0
# DEPARTURE_TIME          1549
# DEPARTURE_DELAY         1549
# TAXI_OUT                1599
# WHEELS_OFF              1599
# SCHEDULED_TIME             0
# ELAPSED_TIME            1872
# AIR_TIME                1872
# DISTANCE                   0
# WHEELS_ON               1667
# TAXI_IN                 1667
# SCHEDULED_ARRIVAL          0
# ARRIVAL_TIME            1667
# ARRIVAL_DELAY           1872
# DIVERTED                   0
# CANCELLED                  0
# CANCELLATION_REASON    98382
# AIR_SYSTEM_DELAY       81784
# SECURITY_DELAY         81784
# AIRLINE_DELAY          81784
# LATE_AIRCRAFT_DELAY    81784
# WEATHER_DELAY          81784
# dtype: int64

# %%
sns.countplot(x='CANCELLATION_REASON',data=flights)
# Out:
# <AxesSubplot:xlabel='CANCELLATION_REASON', ylabel='count'>

# %%
sns.countplot(x="MONTH",hue="CANCELLATION_REASON",data=flights)
# Out:
# <AxesSubplot:xlabel='MONTH', ylabel='count'>

# %%
plt.figure(figsize=(10, 10))
axis = sns.countplot(x=flights['ORIGIN_AIRPORT'], data =flights, order=flights['ORIGIN_AIRPORT'].value_counts().iloc[:20].index)
axis.set_xticklabels(axis.get_xticklabels(), rotation=90, ha="right")
plt.tight_layout()
plt.show()

# %%
axis = plt.subplots(figsize=(10,14))
Name = flights["AIRLINE"].unique()
size = flights["AIRLINE"].value_counts()
plt.pie(size,labels=Name,autopct='%5.0f%%')
plt.show()

# %%
axis = plt.subplots(figsize=(20,14))
sns.heatmap(flights.corr(),annot = True)
plt.show()

# %%
corr=flights.corr()
corr
# Out:
#                      YEAR     MONTH       DAY  DAY_OF_WEEK  FLIGHT_NUMBER  \
# YEAR                  NaN       NaN       NaN          NaN            NaN
# MONTH                 NaN  1.000000  0.010983    -0.010909      -0.021822
# DAY                   NaN  0.010983  1.000000    -0.002444       0.006571
# DAY_OF_WEEK           NaN -0.010909 -0.002444     1.000000       0.009246
# FLIGHT_NUMBER         NaN -0.021822  0.006571     0.009246       1.000000
# SCHEDULED_DEPARTURE   NaN  0.004846 -0.007998     0.011818      -0.005161
# DEPARTURE_TIME        NaN -0.000287 -0.007515     0.010540      -0.000208
# DEPARTURE_DELAY       NaN -0.018828 -0.001546    -0.012975      -0.008939
# TAXI_OUT              NaN -0.013950 -0.009055    -0.021476       0.054797
# WHEELS_OFF            NaN -0.001818 -0.008957     0.009044       0.006736
# SCHEDULED_TIME        NaN  0.013640  0.001045     0.015694      -0.316273
# ELAPSED_TIME          NaN  0.004363 -0.001925     0.012520      -0.305337
# AIR_TIME              NaN  0.005940 -0.000782     0.015307      -0.318696
# DISTANCE              NaN  0.014310  0.000876     0.016757      -0.330379
# WHEELS_ON             NaN -0.002830 -0.005177     0.011590      -0.007037
# TAXI_IN               NaN  0.003917 -0.000831     0.002980      -0.020350
# SCHEDULED_ARRIVAL     NaN -0.007035 -0.004991     0.009807      -0.015709
# ARRIVAL_TIME          NaN -0.003498 -0.005117     0.010365      -0.003933
# ARRIVAL_DELAY         NaN -0.034794 -0.005552    -0.018234       0.017383
# DIVERTED              NaN  0.004609  0.005121    -0.005482       0.006802
# CANCELLED             NaN -0.058389 -0.004821    -0.023303       0.034673
# AIR_SYSTEM_DELAY      NaN -0.014310 -0.018094    -0.023531      -0.013947
# SECURITY_DELAY        NaN  0.003991  0.006717    -0.003252      -0.010148
# AIRLINE_DELAY         NaN  0.012219  0.008012     0.011719       0.008016
# LATE_AIRCRAFT_DELAY   NaN  0.012944  0.019861    -0.030185       0.017309
# WEATHER_DELAY         NaN -0.006602  0.006420    -0.011462       0.003195
#
#                      SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY  \
# YEAR                                 NaN             NaN              NaN
# MONTH                           0.004846       -0.000287        -0.018828
# DAY                            -0.007998       -0.007515        -0.001546
# DAY_OF_WEEK                     0.011818        0.010540        -0.012975
# FLIGHT_NUMBER                  -0.005161       -0.000208        -0.008939
# SCHEDULED_DEPARTURE             1.000000        0.963150         0.115164
# DEPARTURE_TIME                  0.963150        1.000000         0.171178
# DEPARTURE_DELAY                 0.115164        0.171178         1.000000
# TAXI_OUT                       -0.000871        0.007231         0.054761
# WHEELS_OFF                      0.938359        0.973557         0.162064
# SCHEDULED_TIME                 -0.019429       -0.024259         0.030783
# ELAPSED_TIME                   -0.020457       -0.025604         0.033361
# AIR_TIME                       -0.017962       -0.024437         0.027057
# DISTANCE                       -0.013403       -0.020704         0.028352
# WHEELS_ON                       0.656873        0.676818         0.050013
# TAXI_IN                        -0.038223       -0.035601         0.006618
# SCHEDULED_ARRIVAL               0.704449        0.706551         0.098520
# ARRIVAL_TIME                    0.627765        0.646679         0.039821
# ARRIVAL_DELAY                   0.105230        0.159116         0.942490
# DIVERTED                       -0.003038        0.000510         0.037444
# CANCELLED                       0.014687        0.012426         0.039174
# AIR_SYSTEM_DELAY               -0.077185       -0.045725         0.078659
# SECURITY_DELAY                 -0.009734       -0.039197         0.015324
# AIRLINE_DELAY                  -0.084345       -0.026305         0.608008
# LATE_AIRCRAFT_DELAY             0.147724        0.176791         0.589817
# WEATHER_DELAY                  -0.004815       -0.008325         0.212959
#
#                      TAXI_OUT  WHEELS_OFF  ...  SCHEDULED_ARRIVAL  \
# YEAR                      NaN         NaN  ...                NaN
# MONTH               -0.013950   -0.001818  ...          -0.007035
# DAY                 -0.009055   -0.008957  ...          -0.004991
# DAY_OF_WEEK         -0.021476    0.009044  ...           0.009807
# FLIGHT_NUMBER        0.054797    0.006736  ...          -0.015709
# SCHEDULED_DEPARTURE -0.000871    0.938359  ...           0.704449
# DEPARTURE_TIME       0.007231    0.973557  ...           0.706551
# DEPARTURE_DELAY      0.054761    0.162064  ...           0.098520
# TAXI_OUT             1.000000    0.033284  ...           0.017408
# WHEELS_OFF           0.033284    1.000000  ...           0.717687
# SCHEDULED_TIME       0.108020   -0.031640  ...           0.035357
# ELAPSED_TIME         0.201223   -0.030594  ...           0.034007
# AIR_TIME             0.083252   -0.032921  ...           0.032852
# DISTANCE             0.067869   -0.031850  ...           0.030292
# WHEELS_ON            0.026291    0.695075  ...           0.868872
# TAXI_IN              0.005482   -0.033428  ...          -0.001022
# SCHEDULED_ARRIVAL    0.017408    0.717687  ...           1.000000
# ARRIVAL_TIME         0.023303    0.664872  ...           0.860310
# ARRIVAL_DELAY        0.228803    0.155808  ...           0.088843
# DIVERTED             0.019236    0.000661  ...           0.005056
# CANCELLED            0.006972    0.009860  ...           0.012879
# AIR_SYSTEM_DELAY     0.375125   -0.025332  ...          -0.021019
# SECURITY_DELAY      -0.005487   -0.038089  ...          -0.017637
# AIRLINE_DELAY       -0.078346   -0.032791  ...          -0.071397
# LATE_AIRCRAFT_DELAY -0.125869    0.147896  ...           0.107636
# WEATHER_DELAY        0.070656   -0.008733  ...           0.006213
#
#                      ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# YEAR                          NaN            NaN       NaN        NaN
# MONTH                   -0.003498      -0.034794  0.004609  -0.058389
# DAY                     -0.005117      -0.005552  0.005121  -0.004821
# DAY_OF_WEEK              0.010365      -0.018234 -0.005482  -0.023303
# FLIGHT_NUMBER           -0.003933       0.017383  0.006802   0.034673
# SCHEDULED_DEPARTURE      0.627765       0.105230 -0.003038   0.014687
# DEPARTURE_TIME           0.646679       0.159116  0.000510   0.012426
# DEPARTURE_DELAY          0.039821       0.942490  0.037444   0.039174
# TAXI_OUT                 0.023303       0.228803  0.019236   0.006972
# WHEELS_OFF               0.664872       0.155808  0.000661   0.009860
# SCHEDULED_TIME           0.021692      -0.027585  0.013352  -0.025657
# ELAPSED_TIME             0.022773       0.032252       NaN        NaN
# AIR_TIME                 0.020003      -0.003864       NaN        NaN
# DISTANCE                 0.015759      -0.022241  0.011108  -0.031173
# WHEELS_ON                0.964990       0.049887  0.014624        NaN
# TAXI_IN                  0.007339       0.114219  0.018121        NaN
# SCHEDULED_ARRIVAL        0.860310       0.088843  0.005056   0.012879
# ARRIVAL_TIME             1.000000       0.040290  0.014469        NaN
# ARRIVAL_DELAY            0.040290       1.000000       NaN        NaN
# DIVERTED                 0.014469            NaN  1.000000  -0.006471
# CANCELLED                     NaN            NaN -0.006471   1.000000
# AIR_SYSTEM_DELAY         0.014612       0.241904       NaN        NaN
# SECURITY_DELAY          -0.025258       0.010589       NaN        NaN
# AIRLINE_DELAY           -0.058206       0.593745       NaN        NaN
# LATE_AIRCRAFT_DELAY     -0.034052       0.557955       NaN        NaN
# WEATHER_DELAY           -0.030577       0.234709       NaN        NaN
#
#                      AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# YEAR                              NaN             NaN            NaN
# MONTH                       -0.014310        0.003991       0.012219
# DAY                         -0.018094        0.006717       0.008012
# DAY_OF_WEEK                 -0.023531       -0.003252       0.011719
# FLIGHT_NUMBER               -0.013947       -0.010148       0.008016
# SCHEDULED_DEPARTURE         -0.077185       -0.009734      -0.084345
# DEPARTURE_TIME              -0.045725       -0.039197      -0.026305
# DEPARTURE_DELAY              0.078659        0.015324       0.608008
# TAXI_OUT                     0.375125       -0.005487      -0.078346
# WHEELS_OFF                  -0.025332       -0.038089      -0.032791
# SCHEDULED_TIME               0.028949        0.015733       0.041620
# ELAPSED_TIME                 0.156724        0.010829       0.004617
# AIR_TIME                     0.055842        0.013963       0.027312
# DISTANCE                     0.012161        0.016808       0.042772
# WHEELS_ON                    0.016672       -0.026696      -0.061570
# TAXI_IN                      0.264368       -0.012873      -0.055137
# SCHEDULED_ARRIVAL           -0.021019       -0.017637      -0.071397
# ARRIVAL_TIME                 0.014612       -0.025258      -0.058206
# ARRIVAL_DELAY                0.241904        0.010589       0.593745
# DIVERTED                          NaN             NaN            NaN
# CANCELLED                         NaN             NaN            NaN
# AIR_SYSTEM_DELAY             1.000000       -0.013898      -0.127519
# SECURITY_DELAY              -0.013898        1.000000      -0.016210
# AIRLINE_DELAY               -0.127519       -0.016210       1.000000
# LATE_AIRCRAFT_DELAY         -0.140195       -0.017030      -0.102778
# WEATHER_DELAY               -0.001574       -0.006339      -0.056149
#
#                      LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# YEAR                                 NaN            NaN
# MONTH                           0.012944      -0.006602
# DAY                             0.019861       0.006420
# DAY_OF_WEEK                    -0.030185      -0.011462
# FLIGHT_NUMBER                   0.017309       0.003195
# SCHEDULED_DEPARTURE             0.147724      -0.004815
# DEPARTURE_TIME                  0.176791      -0.008325
# DEPARTURE_DELAY                 0.589817       0.212959
# TAXI_OUT                       -0.125869       0.070656
# WHEELS_OFF                      0.147896      -0.008733
# SCHEDULED_TIME                 -0.032809      -0.007097
# ELAPSED_TIME                   -0.081071       0.002180
# AIR_TIME                       -0.050392      -0.011395
# DISTANCE                       -0.030757      -0.015251
# WHEELS_ON                      -0.023910      -0.027256
# TAXI_IN                        -0.072711      -0.005249
# SCHEDULED_ARRIVAL               0.107636       0.006213
# ARRIVAL_TIME                   -0.034052      -0.030577
# ARRIVAL_DELAY                   0.557955       0.234709
# DIVERTED                             NaN            NaN
# CANCELLED                            NaN            NaN
# AIR_SYSTEM_DELAY               -0.140195      -0.001574
# SECURITY_DELAY                 -0.017030      -0.006339
# AIRLINE_DELAY                  -0.102778      -0.056149
# LATE_AIRCRAFT_DELAY             1.000000      -0.010278
# WEATHER_DELAY                  -0.010278       1.000000
#
# [26 rows x 26 columns]

# %%
variables_to_remove=["YEAR","FLIGHT_NUMBER","TAIL_NUMBER","DEPARTURE_TIME","TAXI_OUT","WHEELS_OFF","ELAPSED_TIME","AIR_TIME","WHEELS_ON","TAXI_IN","ARRIVAL_TIME","DIVERTED","CANCELLED","CANCELLATION_REASON","AIR_SYSTEM_DELAY", "SECURITY_DELAY","AIRLINE_DELAY","LATE_AIRCRAFT_DELAY","WEATHER_DELAY","SCHEDULED_TIME","SCHEDULED_ARRIVAL"]
flights.drop(variables_to_remove,axis=1,inplace= True)
flights.columns
# Out:
# Index(['MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'ORIGIN_AIRPORT',
#        'DESTINATION_AIRPORT', 'SCHEDULED_DEPARTURE', 'DEPARTURE_DELAY',
#        'DISTANCE', 'ARRIVAL_DELAY'],
#       dtype='object')

# %%
airport = pd.read_csv('airports.csv')
airport
# Out:
#     IATA_CODE                              AIRPORT  \
# 0         ABE  Lehigh Valley International Airport
# 1         ABI             Abilene Regional Airport
# 2         ABQ    Albuquerque International Sunport
# 3         ABR            Aberdeen Regional Airport
# 4         ABY   Southwest Georgia Regional Airport
# ..        ...                                  ...
# 317       WRG                     Wrangell Airport
# 318       WYS               Westerly State Airport
# 319       XNA  Northwest Arkansas Regional Airport
# 320       YAK                      Yakutat Airport
# 321       YUM           Yuma International Airport
#
#                                CITY STATE COUNTRY  LATITUDE  LONGITUDE
# 0                         Allentown    PA     USA  40.65236  -75.44040
# 1                           Abilene    TX     USA  32.41132  -99.68190
# 2                       Albuquerque    NM     USA  35.04022 -106.60919
# 3                          Aberdeen    SD     USA  45.44906  -98.42183
# 4                            Albany    GA     USA  31.53552  -84.19447
# ..                              ...   ...     ...       ...        ...
# 317                        Wrangell    AK     USA  56.48433 -132.36982
# 318                West Yellowstone    MT     USA  44.68840 -111.11764
# 319  Fayetteville/Springdale/Rogers    AR     USA  36.28187  -94.30681
# 320                         Yakutat    AK     USA  59.50336 -139.66023
# 321                            Yuma    AZ     USA  32.65658 -114.60597
#
# [322 rows x 7 columns]

# %%
flights.loc[~flights.ORIGIN_AIRPORT.isin(airport.IATA_CODE.values),'ORIGIN_AIRPORT']='OTHER'
flights.loc[~flights.DESTINATION_AIRPORT.isin(airport.IATA_CODE.values),'DESTINATION_AIRPORT']='OTHER'
flights
# Out:
#          MONTH  DAY  DAY_OF_WEEK AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 5652583     12   21            1      MQ            BMI                 DFW
# 5611793     12   18            5      EV            CAK                 ORD
# 96010        1    7            3      OO            ONT                 IAH
# 3817197      8   25            2      DL            CLE                 ATL
# 3608399      8   12            3      OO            IDA                 SLC
# ...        ...  ...          ...     ...            ...                 ...
# 5299285     11   28            6      WN            SAT                 ATL
# 2253612      5   23            6      WN            AMA                 DAL
# 2274508      5   25            1      MQ            BNA                 LGA
# 4562441     10   12            1      EV          OTHER               OTHER
# 637429       2   12            4      WN            STL                 MCI
#
#          SCHEDULED_DEPARTURE  DEPARTURE_DELAY  DISTANCE  ARRIVAL_DELAY
# 5652583                  720             -3.0       690           -6.0
# 5611793                 1357             -3.0       343          -13.0
# 96010                    701              4.0      1334           20.0
# 3817197                 1419             -8.0       554          -19.0
# 3608399                 1820              3.0       188            0.0
# ...                      ...              ...       ...            ...
# 5299285                 1550             53.0       874           57.0
# 2253612                 1340             -3.0       323           14.0
# 2274508                  755              2.0       764            4.0
# 4562441                  910             -8.0       986          -17.0
# 637429                   705             66.0       237           55.0
#
# [100000 rows x 10 columns]

# %%
print(flights.ORIGIN_AIRPORT.nunique())
print(flights.DESTINATION_AIRPORT.nunique())
print(flights.AIRLINE.nunique())
# Out:
# 321
# 318
# 14

# %%
flights=flights.dropna()
flights
# Out:
#          MONTH  DAY  DAY_OF_WEEK AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 5652583     12   21            1      MQ            BMI                 DFW
# 5611793     12   18            5      EV            CAK                 ORD
# 96010        1    7            3      OO            ONT                 IAH
# 3817197      8   25            2      DL            CLE                 ATL
# 3608399      8   12            3      OO            IDA                 SLC
# ...        ...  ...          ...     ...            ...                 ...
# 5299285     11   28            6      WN            SAT                 ATL
# 2253612      5   23            6      WN            AMA                 DAL
# 2274508      5   25            1      MQ            BNA                 LGA
# 4562441     10   12            1      EV          OTHER               OTHER
# 637429       2   12            4      WN            STL                 MCI
#
#          SCHEDULED_DEPARTURE  DEPARTURE_DELAY  DISTANCE  ARRIVAL_DELAY
# 5652583                  720             -3.0       690           -6.0
# 5611793                 1357             -3.0       343          -13.0
# 96010                    701              4.0      1334           20.0
# 3817197                 1419             -8.0       554          -19.0
# 3608399                 1820              3.0       188            0.0
# ...                      ...              ...       ...            ...
# 5299285                 1550             53.0       874           57.0
# 2253612                 1340             -3.0       323           14.0
# 2274508                  755              2.0       764            4.0
# 4562441                  910             -8.0       986          -17.0
# 637429                   705             66.0       237           55.0
#
# [98128 rows x 10 columns]

# %%
flights.shape
# Out:
# (98128, 10)

# %%
df=pd.DataFrame(flights)
df['DAY_OF_WEEK']= df['DAY_OF_WEEK'].apply(str)
df["DAY_OF_WEEK"].replace({"1":"SUNDAY", "2": "MONDAY", "3": "TUESDAY", "4":"WEDNESDAY", "5":"THURSDAY", "6":"FRIDAY", "7":"SATURDAY"},inplace=True)
flights
# Out:
#          MONTH  DAY DAY_OF_WEEK AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 5652583     12   21      SUNDAY      MQ            BMI                 DFW
# 5611793     12   18    THURSDAY      EV            CAK                 ORD
# 96010        1    7     TUESDAY      OO            ONT                 IAH
# 3817197      8   25      MONDAY      DL            CLE                 ATL
# 3608399      8   12     TUESDAY      OO            IDA                 SLC
# ...        ...  ...         ...     ...            ...                 ...
# 5299285     11   28      FRIDAY      WN            SAT                 ATL
# 2253612      5   23      FRIDAY      WN            AMA                 DAL
# 2274508      5   25      SUNDAY      MQ            BNA                 LGA
# 4562441     10   12      SUNDAY      EV          OTHER               OTHER
# 637429       2   12   WEDNESDAY      WN            STL                 MCI
#
#          SCHEDULED_DEPARTURE  DEPARTURE_DELAY  DISTANCE  ARRIVAL_DELAY
# 5652583                  720             -3.0       690           -6.0
# 5611793                 1357             -3.0       343          -13.0
# 96010                    701              4.0      1334           20.0
# 3817197                 1419             -8.0       554          -19.0
# 3608399                 1820              3.0       188            0.0
# ...                      ...              ...       ...            ...
# 5299285                 1550             53.0       874           57.0
# 2253612                 1340             -3.0       323           14.0
# 2274508                  755              2.0       764            4.0
# 4562441                  910             -8.0       986          -17.0
# 637429                   705             66.0       237           55.0
#
# [98128 rows x 10 columns]

# %%
dums = ['AIRLINE','ORIGIN_AIRPORT','DESTINATION_AIRPORT','DAY_OF_WEEK']
df_cat=pd.get_dummies(df[dums],drop_first=True)
df_cat
# Out:
#          AIRLINE_AS  AIRLINE_B6  AIRLINE_DL  AIRLINE_EV  AIRLINE_F9  \
# 5652583           0           0           0           0           0
# 5611793           0           0           0           1           0
# 96010             0           0           0           0           0
# 3817197           0           0           1           0           0
# 3608399           0           0           0           0           0
# ...             ...         ...         ...         ...         ...
# 5299285           0           0           0           0           0
# 2253612           0           0           0           0           0
# 2274508           0           0           0           0           0
# 4562441           0           0           0           1           0
# 637429            0           0           0           0           0
#
#          AIRLINE_HA  AIRLINE_MQ  AIRLINE_NK  AIRLINE_OO  AIRLINE_UA  ...  \
# 5652583           0           1           0           0           0  ...
# 5611793           0           0           0           0           0  ...
# 96010             0           0           0           1           0  ...
# 3817197           0           0           0           0           0  ...
# 3608399           0           0           0           1           0  ...
# ...             ...         ...         ...         ...         ...  ...
# 5299285           0           0           0           0           0  ...
# 2253612           0           0           0           0           0  ...
# 2274508           0           1           0           0           0  ...
# 4562441           0           0           0           0           0  ...
# 637429            0           0           0           0           0  ...
#
#          DESTINATION_AIRPORT_WRG  DESTINATION_AIRPORT_XNA  \
# 5652583                        0                        0
# 5611793                        0                        0
# 96010                          0                        0
# 3817197                        0                        0
# 3608399                        0                        0
# ...                          ...                      ...
# 5299285                        0                        0
# 2253612                        0                        0
# 2274508                        0                        0
# 4562441                        0                        0
# 637429                         0                        0
#
#          DESTINATION_AIRPORT_YAK  DESTINATION_AIRPORT_YUM  DAY_OF_WEEK_MONDAY  \
# 5652583                        0                        0                   0
# 5611793                        0                        0                   0
# 96010                          0                        0                   0
# 3817197                        0                        0                   1
# 3608399                        0                        0                   0
# ...                          ...                      ...                 ...
# 5299285                        0                        0                   0
# 2253612                        0                        0                   0
# 2274508                        0                        0                   0
# 4562441                        0                        0                   0
# 637429                         0                        0                   0
#
#          DAY_OF_WEEK_SATURDAY  DAY_OF_WEEK_SUNDAY  DAY_OF_WEEK_THURSDAY  \
# 5652583                     0                   1                     0
# 5611793                     0                   0                     1
# 96010                       0                   0                     0
# 3817197                     0                   0                     0
# 3608399                     0                   0                     0
# ...                       ...                 ...                   ...
# 5299285                     0                   0                     0
# 2253612                     0                   0                     0
# 2274508                     0                   1                     0
# 4562441                     0                   1                     0
# 637429                      0                   0                     0
#
#          DAY_OF_WEEK_TUESDAY  DAY_OF_WEEK_WEDNESDAY
# 5652583                    0                      0
# 5611793                    0                      0
# 96010                      1                      0
# 3817197                    0                      0
# 3608399                    1                      0
# ...                      ...                    ...
# 5299285                    0                      0
# 2253612                    0                      0
# 2274508                    0                      0
# 4562441                    0                      0
# 637429                     0                      1
#
# [98128 rows x 656 columns]

# %%
df_cat.columns
# Out:
# Index(['AIRLINE_AS', 'AIRLINE_B6', 'AIRLINE_DL', 'AIRLINE_EV', 'AIRLINE_F9',
#        'AIRLINE_HA', 'AIRLINE_MQ', 'AIRLINE_NK', 'AIRLINE_OO', 'AIRLINE_UA',
#        ...
#        'DESTINATION_AIRPORT_WRG', 'DESTINATION_AIRPORT_XNA',
#        'DESTINATION_AIRPORT_YAK', 'DESTINATION_AIRPORT_YUM',
#        'DAY_OF_WEEK_MONDAY', 'DAY_OF_WEEK_SATURDAY', 'DAY_OF_WEEK_SUNDAY',
#        'DAY_OF_WEEK_THURSDAY', 'DAY_OF_WEEK_TUESDAY', 'DAY_OF_WEEK_WEDNESDAY'],
#       dtype='object', length=656)

# %%
df.columns
# Out:
# Index(['MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'ORIGIN_AIRPORT',
#        'DESTINATION_AIRPORT', 'SCHEDULED_DEPARTURE', 'DEPARTURE_DELAY',
#        'DISTANCE', 'ARRIVAL_DELAY'],
#       dtype='object')

# %%
flights.columns
# Out:
# Index(['MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'ORIGIN_AIRPORT',
#        'DESTINATION_AIRPORT', 'SCHEDULED_DEPARTURE', 'DEPARTURE_DELAY',
#        'DISTANCE', 'ARRIVAL_DELAY'],
#       dtype='object')

# %%
var_to_remove=["DAY_OF_WEEK","AIRLINE","ORIGIN_AIRPORT","DESTINATION_AIRPORT"]
df.drop(var_to_remove,axis=1,inplace=True)
df
# Out:
#          MONTH  DAY  SCHEDULED_DEPARTURE  DEPARTURE_DELAY  DISTANCE  \
# 5652583     12   21                  720             -3.0       690
# 5611793     12   18                 1357             -3.0       343
# 96010        1    7                  701              4.0      1334
# 3817197      8   25                 1419             -8.0       554
# 3608399      8   12                 1820              3.0       188
# ...        ...  ...                  ...              ...       ...
# 5299285     11   28                 1550             53.0       874
# 2253612      5   23                 1340             -3.0       323
# 2274508      5   25                  755              2.0       764
# 4562441     10   12                  910             -8.0       986
# 637429       2   12                  705             66.0       237
#
#          ARRIVAL_DELAY
# 5652583           -6.0
# 5611793          -13.0
# 96010             20.0
# 3817197          -19.0
# 3608399            0.0
# ...                ...
# 5299285           57.0
# 2253612           14.0
# 2274508            4.0
# 4562441          -17.0
# 637429            55.0
#
# [98128 rows x 6 columns]

# %%
data=pd.concat([df,df_cat],axis=1)
data
# Out:
#          MONTH  DAY  SCHEDULED_DEPARTURE  DEPARTURE_DELAY  DISTANCE  \
# 5652583     12   21                  720             -3.0       690
# 5611793     12   18                 1357             -3.0       343
# 96010        1    7                  701              4.0      1334
# 3817197      8   25                 1419             -8.0       554
# 3608399      8   12                 1820              3.0       188
# ...        ...  ...                  ...              ...       ...
# 5299285     11   28                 1550             53.0       874
# 2253612      5   23                 1340             -3.0       323
# 2274508      5   25                  755              2.0       764
# 4562441     10   12                  910             -8.0       986
# 637429       2   12                  705             66.0       237
#
#          ARRIVAL_DELAY  AIRLINE_AS  AIRLINE_B6  AIRLINE_DL  AIRLINE_EV  ...  \
# 5652583           -6.0           0           0           0           0  ...
# 5611793          -13.0           0           0           0           1  ...
# 96010             20.0           0           0           0           0  ...
# 3817197          -19.0           0           0           1           0  ...
# 3608399            0.0           0           0           0           0  ...
# ...                ...         ...         ...         ...         ...  ...
# 5299285           57.0           0           0           0           0  ...
# 2253612           14.0           0           0           0           0  ...
# 2274508            4.0           0           0           0           0  ...
# 4562441          -17.0           0           0           0           1  ...
# 637429            55.0           0           0           0           0  ...
#
#          DESTINATION_AIRPORT_WRG  DESTINATION_AIRPORT_XNA  \
# 5652583                        0                        0
# 5611793                        0                        0
# 96010                          0                        0
# 3817197                        0                        0
# 3608399                        0                        0
# ...                          ...                      ...
# 5299285                        0                        0
# 2253612                        0                        0
# 2274508                        0                        0
# 4562441                        0                        0
# 637429                         0                        0
#
#          DESTINATION_AIRPORT_YAK  DESTINATION_AIRPORT_YUM  DAY_OF_WEEK_MONDAY  \
# 5652583                        0                        0                   0
# 5611793                        0                        0                   0
# 96010                          0                        0                   0
# 3817197                        0                        0                   1
# 3608399                        0                        0                   0
# ...                          ...                      ...                 ...
# 5299285                        0                        0                   0
# 2253612                        0                        0                   0
# 2274508                        0                        0                   0
# 4562441                        0                        0                   0
# 637429                         0                        0                   0
#
#          DAY_OF_WEEK_SATURDAY  DAY_OF_WEEK_SUNDAY  DAY_OF_WEEK_THURSDAY  \
# 5652583                     0                   1                     0
# 5611793                     0                   0                     1
# 96010                       0                   0                     0
# 3817197                     0                   0                     0
# 3608399                     0                   0                     0
# ...                       ...                 ...                   ...
# 5299285                     0                   0                     0
# 2253612                     0                   0                     0
# 2274508                     0                   1                     0
# 4562441                     0                   1                     0
# 637429                      0                   0                     0
#
#          DAY_OF_WEEK_TUESDAY  DAY_OF_WEEK_WEDNESDAY
# 5652583                    0                      0
# 5611793                    0                      0
# 96010                      1                      0
# 3817197                    0                      0
# 3608399                    1                      0
# ...                      ...                    ...
# 5299285                    0                      0
# 2253612                    0                      0
# 2274508                    0                      0
# 4562441                    0                      0
# 637429                     0                      1
#
# [98128 rows x 662 columns]

# %%
data.shape
# Out:
# (98128, 662)

# %%
final_data = data.sample(n=60000)
final_data
# Out:
#          MONTH  DAY  SCHEDULED_DEPARTURE  DEPARTURE_DELAY  DISTANCE  \
# 2570270      6   11                 2230             -8.0       802
# 3815241      8   25                 1220              2.0      1999
# 100829       1    7                 1200             -1.0       255
# 1879536      4   30                 1245             -9.0       329
# 2371315      5   31                  730             -4.0      1846
# ...        ...  ...                  ...              ...       ...
# 2347980      5   29                 1355            -10.0       954
# 309221       1   21                 1000              0.0       423
# 3989918      9    5                  845              0.0       621
# 1718483      4   20                 1415              5.0       472
# 297143       1   20                 1315              2.0      1079
#
#          ARRIVAL_DELAY  AIRLINE_AS  AIRLINE_B6  AIRLINE_DL  AIRLINE_EV  ...  \
# 2570270            8.0           0           0           0           0  ...
# 3815241           -6.0           0           0           0           0  ...
# 100829             0.0           0           0           0           0  ...
# 1879536          -24.0           0           0           0           0  ...
# 2371315          -26.0           0           0           0           0  ...
# ...                ...         ...         ...         ...         ...  ...
# 2347980          -18.0           1           0           0           0  ...
# 309221            13.0           0           0           0           0  ...
# 3989918           -6.0           0           0           0           0  ...
# 1718483           -5.0           0           0           0           0  ...
# 297143           -14.0           0           0           0           0  ...
#
#          DESTINATION_AIRPORT_WRG  DESTINATION_AIRPORT_XNA  \
# 2570270                        0                        0
# 3815241                        0                        0
# 100829                         0                        0
# 1879536                        0                        0
# 2371315                        0                        0
# ...                          ...                      ...
# 2347980                        0                        0
# 309221                         0                        0
# 3989918                        0                        0
# 1718483                        0                        0
# 297143                         0                        0
#
#          DESTINATION_AIRPORT_YAK  DESTINATION_AIRPORT_YUM  DAY_OF_WEEK_MONDAY  \
# 2570270                        0                        0                   0
# 3815241                        0                        0                   1
# 100829                         0                        0                   0
# 1879536                        0                        0                   0
# 2371315                        0                        0                   0
# ...                          ...                      ...                 ...
# 2347980                        0                        0                   0
# 309221                         0                        0                   0
# 3989918                        0                        0                   0
# 1718483                        0                        0                   0
# 297143                         0                        0                   1
#
#          DAY_OF_WEEK_SATURDAY  DAY_OF_WEEK_SUNDAY  DAY_OF_WEEK_THURSDAY  \
# 2570270                     0                   0                     0
# 3815241                     0                   0                     0
# 100829                      0                   0                     0
# 1879536                     0                   0                     0
# 2371315                     1                   0                     0
# ...                       ...                 ...                   ...
# 2347980                     0                   0                     1
# 309221                      0                   0                     0
# 3989918                     0                   0                     0
# 1718483                     0                   1                     0
# 297143                      0                   0                     0
#
#          DAY_OF_WEEK_TUESDAY  DAY_OF_WEEK_WEDNESDAY
# 2570270                    0                      1
# 3815241                    0                      0
# 100829                     1                      0
# 1879536                    0                      1
# 2371315                    0                      0
# ...                      ...                    ...
# 2347980                    0                      0
# 309221                     1                      0
# 3989918                    0                      0
# 1718483                    0                      0
# 297143                     0                      0
#
# [60000 rows x 662 columns]

# %%
final_data.shape
# Out:
# (60000, 662)

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
X=final_data.drop("DEPARTURE_DELAY",axis=1)
Y=final_data.DEPARTURE_DELAY

# %%
X
# Out:
#          MONTH  DAY  SCHEDULED_DEPARTURE  DISTANCE  ARRIVAL_DELAY  AIRLINE_AS  \
# 2570270      6   11                 2230       802            8.0           0
# 3815241      8   25                 1220      1999           -6.0           0
# 100829       1    7                 1200       255            0.0           0
# 1879536      4   30                 1245       329          -24.0           0
# 2371315      5   31                  730      1846          -26.0           0
# ...        ...  ...                  ...       ...            ...         ...
# 2347980      5   29                 1355       954          -18.0           1
# 309221       1   21                 1000       423           13.0           0
# 3989918      9    5                  845       621           -6.0           0
# 1718483      4   20                 1415       472           -5.0           0
# 297143       1   20                 1315      1079          -14.0           0
#
#          AIRLINE_B6  AIRLINE_DL  AIRLINE_EV  AIRLINE_F9  ...  \
# 2570270           0           0           0           0  ...
# 3815241           0           0           0           0  ...
# 100829            0           0           0           0  ...
# 1879536           0           0           0           0  ...
# 2371315           0           0           0           0  ...
# ...             ...         ...         ...         ...  ...
# 2347980           0           0           0           0  ...
# 309221            0           0           0           0  ...
# 3989918           0           0           0           0  ...
# 1718483           0           0           0           0  ...
# 297143            0           0           0           0  ...
#
#          DESTINATION_AIRPORT_WRG  DESTINATION_AIRPORT_XNA  \
# 2570270                        0                        0
# 3815241                        0                        0
# 100829                         0                        0
# 1879536                        0                        0
# 2371315                        0                        0
# ...                          ...                      ...
# 2347980                        0                        0
# 309221                         0                        0
# 3989918                        0                        0
# 1718483                        0                        0
# 297143                         0                        0
#
#          DESTINATION_AIRPORT_YAK  DESTINATION_AIRPORT_YUM  DAY_OF_WEEK_MONDAY  \
# 2570270                        0                        0                   0
# 3815241                        0                        0                   1
# 100829                         0                        0                   0
# 1879536                        0                        0                   0
# 2371315                        0                        0                   0
# ...                          ...                      ...                 ...
# 2347980                        0                        0                   0
# 309221                         0                        0                   0
# 3989918                        0                        0                   0
# 1718483                        0                        0                   0
# 297143                         0                        0                   1
#
#          DAY_OF_WEEK_SATURDAY  DAY_OF_WEEK_SUNDAY  DAY_OF_WEEK_THURSDAY  \
# 2570270                     0                   0                     0
# 3815241                     0                   0                     0
# 100829                      0                   0                     0
# 1879536                     0                   0                     0
# 2371315                     1                   0                     0
# ...                       ...                 ...                   ...
# 2347980                     0                   0                     1
# 309221                      0                   0                     0
# 3989918                     0                   0                     0
# 1718483                     0                   1                     0
# 297143                      0                   0                     0
#
#          DAY_OF_WEEK_TUESDAY  DAY_OF_WEEK_WEDNESDAY
# 2570270                    0                      1
# 3815241                    0                      0
# 100829                     1                      0
# 1879536                    0                      1
# 2371315                    0                      0
# ...                      ...                    ...
# 2347980                    0                      0
# 309221                     1                      0
# 3989918                    0                      0
# 1718483                    0                      0
# 297143                     0                      0
#
# [60000 rows x 661 columns]

# %%
Y
# Out:
# 2570270    -8.0
# 3815241     2.0
# 100829     -1.0
# 1879536    -9.0
# 2371315    -4.0
#            ...
# 2347980   -10.0
# 309221      0.0
# 3989918     0.0
# 1718483     5.0
# 297143      2.0
# Name: DEPARTURE_DELAY, Length: 60000, dtype: float64

# %%
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor
reg_rf = RandomForestRegressor()
reg_rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = reg_rf.predict(X_test)

# %%
reg_rf.score(X_train,y_train)
# Out:
# 0.989122824659746

# %%
reg_rf.score(X_test,y_test)
# Out:
# 0.9181089791536308

# %%
metrics.r2_score(y_test,y_pred)
# Out:
# 0.9181089791536308

# %%
print('MAE:', metrics.mean_absolute_error(y_test,y_pred))
print('MSE:', metrics.mean_squared_error(y_test,y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# MAE: 5.929583333333333
# MSE: 95.10026993333335
# RMSE: 9.751936727303626

# %%
from sklearn.model_selection import RandomizedSearchCV
#Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 10, stop = 200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

# %%
rf_random = RandomizedSearchCV(
    estimator=reg_rf,
    param_distributions=random_grid,
    scoring='neg_mean_squared_error',
    n_iter=10,  # Number of random combinations of hyperparameters to try
    cv=5,       # Number of cross-validation folds
    verbose=2,
    random_state=42,
    n_jobs=-1    # Number of CPU cores to use for parallel computation
)

# %%
rf_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# C:\Users\alapa\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 20 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 14 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\alapa\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\alapa\anaconda3\lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\alapa\anaconda3\lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\alapa\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\alapa\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\alapa\anaconda3\lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\alapa\anaconda3\lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\alapa\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\alapa\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [ -888.55100778  -749.54869996            nan            nan
#             nan  -559.94625386 -1111.13818906  -776.00403705
#  -1079.84314205            nan]
#   warnings.warn(
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [10, 27, 44, 61, 79, 96,
#                                                          113, 130, 148, 165,
#                                                          182, 200]},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 165,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': 25}

# %%
p=rf_random.predict(X_test)

# %%
metrics.r2_score(y_test,p)
# Out:
# 0.6421509519286486

# %%
print('MAE:', metrics.mean_absolute_error(y_test,p))
print('MSE:', metrics.mean_squared_error(y_test,p))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test,p)))
# Out:
# MAE: 11.341817854550737
# MSE: 415.5710933292234
# RMSE: 20.38556090298286

# %%
zz=pd.DataFrame({'Actual':y_test,'Predicted':p})
zz
# Out:
#          Actual  Predicted
# 5147937    -4.0   1.832005
# 3122913    -4.0  -1.735787
# 3899055    -5.0   7.323300
# 4646879    -2.0  -0.746252
# 3254464    -1.0   6.779078
# ...         ...        ...
# 3914036     4.0  10.945204
# 2566028    22.0  10.941960
# 757694     22.0  10.050406
# 3714140     0.0   1.486167
# 5360225    -8.0   1.036755
#
# [12000 rows x 2 columns]

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor(random_state=0)

# %%
GBR=gbr.fit(X_train,y_train)
pre=GBR.predict(X_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test,pre))
print('MSE:', metrics.mean_squared_error(y_test,pre))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test,pre)))
# Out:
# MAE: 5.946308966325523
# MSE: 92.30945382371465
# RMSE: 9.607780900068166

# %%
metrics.r2_score(y_test,pre)
# Out:
# 0.9205121561411553

# %%
def predict(MONTH, DAY,SCHEDULED_DEPARTURE,DISTANCE, ARRIVAL_DELAY,AIRLINE,ORIGIN_AIRPORT,DESTINATION_AIRPORT,DAY_OF_WEEK):
    AIRLINE_index = np.where(X.columns==AIRLINE)[0][0]
    ORIGIN_index = np.where(X.columns==ORIGIN_AIRPORT)[0][0]
    DESTINATION_index = np.where(X.columns==DESTINATION_AIRPORT)[0][0]
    DAY_OF_WEEK_index = np.where(X.columns==DAY_OF_WEEK)[0][0]
    x= np.zeros(len(X.columns))
    x[0] = MONTH
    x[1] = DAY
    x[2] = SCHEDULED_DEPARTURE
    x[3] = DISTANCE
    x[4] = ARRIVAL_DELAY
    if AIRLINE_index >=0:
        x[AIRLINE_index] = 1
    if ORIGIN_index >=0:
        x[ORIGIN_index] = 1
    if DESTINATION_index >=0:
        x[DESTINATION_index] = 1
    if  DAY_OF_WEEK_index >= 0:
        x[ DAY_OF_WEEK_index] = 1

    return gbr.predict([x])[0]

# %%
res= predict(5,6,1515,328,-8.0,'AIRLINE_OO','ORIGIN_AIRPORT_PHX','DESTINATION_AIRPORT_ABQ','DAY_OF_WEEK_TUESDAY')
res
# Out:
# C:\Users\alapa\anaconda3\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# -4.336079550308974

# %%
if(res<=-15):
  print("Flight is delayed")
else:
  print("Flight is not delayed")
# Out:
# Flight is not delayed
